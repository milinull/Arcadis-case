# %%
import pandas as pd

df = pd.read_excel("../pdf/Material_Case_Ex3.xlsx", sheet_name="EZMtp")

df = df.drop(columns=df.columns[:3])
df = df.drop(index=[1, 2])
df.columns = df.iloc[0]
df = df.iloc[1:].reset_index(drop=True)

df.head(10)
# Out:
# 0 #sys_loc_code measurement_date ("DD/MM/AA HH:MM")       NaN  \
# 0     M08_44077                 2023-12-27 00:00:00  09:41:00
# 1    PU07_45262                 2023-12-27 00:00:00  09:58:00
# 2   PU7,5_45262                 2023-12-27 00:00:00  10:10:00
# 3    M8,5_45276                 2023-12-27 00:00:00  10:21:00
# 4   PT8,5_45276                 2023-12-27 00:00:00  10:34:00
# 5   PT9,5_45276                 2023-12-27 00:00:00  10:43:00
# 6     PU9_45262                 2023-12-27 00:00:00  10:57:00
# 7     M08_44077                 2023-12-27 00:00:00  08:51:00
# 8    PU07_45262                 2023-12-27 00:00:00  09:07:00
# 9   PU7,5_45262                 2023-12-27 00:00:00  09:21:00
#
# 0   measurement_method   remark Temp C Cond elet (uS/cm) OD (mg/l) pH (-)  \
# 0  Coleta de água sup.  Sonda X     21             10000       4.1      7
# 1  Coleta de água sup.  Sonda X     22             10001       4.2      7
# ...
